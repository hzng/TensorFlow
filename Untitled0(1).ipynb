# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# %%
p = [0.5,0.5]
H=0
for i in p:
  H -= i*np.log2(i)
print(H)
# Out:
# nan
# <ipython-input-13-88501f78e490>:4: RuntimeWarning: divide by zero encountered in log2
#   H -= i*np.log2(i)
# <ipython-input-13-88501f78e490>:4: RuntimeWarning: invalid value encountered in scalar multiply
#   H -= i*np.log2(i)
